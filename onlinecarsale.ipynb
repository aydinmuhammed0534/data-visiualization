# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("online_car-sales.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  unnamed               customer_id  advertisement_number  \
# 0           0    89732  5e179871bc3087fa6cb10a21             777375802
# 1           1    89733  5e179871bc3087fa6cb10a22             777255310
# 2           2    89734  5e179871bc3087fa6cb10a23             776963108
# 3           3    89735  5e179871bc3087fa6cb10a24             776938945
# 4           4    89736  5e179871bc3087fa6cb10a25             776932300
#
#         brand  model               variant  year  kilometer        color  \
# 0  Volkswagen   Golf       1.6 FSi Midline  2005      186.0     dark_red
# 1  Volkswagen   Golf  1.2 TSI Midline Plus  2016       13.6          red
# 2  Volkswagen  Jetta     1.2 TSI Trendline  2012      108.0        white
# 3  Volkswagen  Jetta   1.4 TSI Comfortline  2008      157.0         blue
# 4  Volkswagen  Jetta     1.2 TSI Trendline  2012      127.0  silver_gray
#
#   transmission      fuel      city    ad_date      price
# ...

# %%
df.shape
# Out:
# (7600, 15)

# %%
df.tail(20)
# Out:
#       Unnamed: 0  unnamed               customer_id  advertisement_number  \
# 7580        7198    96930  5e179871bc3087fa6cb1263f             769136354
# 7581        7199    96931  5e179871bc3087fa6cb12640             777376485
# 7582        7200    96932  5e179871bc3087fa6cb12641             776549150
# 7583        7201    96933  5e179871bc3087fa6cb12642             776544583
# 7584        7202    96934  5e179871bc3087fa6cb12643             776556780
# 7585        7203    96935  5e179871bc3087fa6cb12644             777331734
# 7586        7204    96936  5e179871bc3087fa6cb12645             777289104
# 7587        7205    96937  5e179871bc3087fa6cb12646             684659170
# 7588        7206    96938  5e179871bc3087fa6cb12647             716131943
# 7589        7207    96939  5e179871bc3087fa6cb12648             777288050
# 7590        7208    96940  5e179871bc3087fa6cb12649             776496507
# 7591        7209    96941  5e179871bc3087fa6cb1264a             774002519
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0       unnamed  advertisement_number         year  \
# count  7600.000000   7600.000000          7.600000e+03  7600.000000
# mean   3797.317632  93529.187105          7.698635e+08  2009.295658
# std    2190.491641   2190.270544          2.355947e+07     6.420218
# min       0.000000  89732.000000          1.954600e+08  1974.000000
# 25%    1899.750000  91631.750000          7.711791e+08  2004.000000
# 50%    3799.500000  93531.500000          7.764830e+08  2011.000000
# 75%    5699.250000  95431.250000          7.773369e+08  2014.000000
# max    7544.000000  97247.000000          7.778354e+08  2020.000000
#
#          kilometer
# count  7599.000000
# mean    157.105202
# std      85.190352
# min       0.000000
# 25%      92.000000
# 50%     153.000000
# 75%     216.500000
# max     980.000000

# %%
df.describe().T
# Out:
#                        count          mean           std          min  \
# Unnamed: 0            7600.0  3.797318e+03  2.190492e+03          0.0
# unnamed               7600.0  9.352919e+04  2.190271e+03      89732.0
# advertisement_number  7600.0  7.698635e+08  2.355947e+07  195460036.0
# year                  7600.0  2.009296e+03  6.420218e+00       1974.0
# kilometer             7599.0  1.571052e+02  8.519035e+01          0.0
#
#                                25%          50%           75%          max
# Unnamed: 0            1.899750e+03       3799.5  5.699250e+03       7544.0
# unnamed               9.163175e+04      93531.5  9.543125e+04      97247.0
# advertisement_number  7.711791e+08  776482958.5  7.773369e+08  777835401.0
# year                  2.004000e+03       2011.0  2.014000e+03       2020.0
# kilometer             9.200000e+01        153.0  2.165000e+02        980.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7600 entries, 0 to 7599
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            7600 non-null   int64
#  1   unnamed               7600 non-null   int64
#  2   customer_id           7590 non-null   object
#  3   advertisement_number  7600 non-null   int64
#  4   brand                 7585 non-null   object
#  5   model                 7600 non-null   object
#  6   variant               7600 non-null   object
#  7   year                  7600 non-null   int64
#  8   kilometer             7599 non-null   float64
#  9   color                 7600 non-null   object
#  10  transmission          7600 non-null   object
#  11  fuel                  7600 non-null   object
#  12  city                  7597 non-null   object
#  13  ad_date               7593 non-null   object
#  14  price                 7600 non-null   object
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  unnamed               customer_id  advertisement_number  \
# 0           0    89732  5e179871bc3087fa6cb10a21             777375802
# 1           1    89733  5e179871bc3087fa6cb10a22             777255310
# 2           2    89734  5e179871bc3087fa6cb10a23             776963108
# 3           3    89735  5e179871bc3087fa6cb10a24             776938945
# 4           4    89736  5e179871bc3087fa6cb10a25             776932300
#
#         brand  model               variant  year  kilometer        color  \
# 0  Volkswagen   Golf       1.6 FSi Midline  2005      186.0     dark_red
# 1  Volkswagen   Golf  1.2 TSI Midline Plus  2016       13.6          red
# 2  Volkswagen  Jetta     1.2 TSI Trendline  2012      108.0        white
# 3  Volkswagen  Jetta   1.4 TSI Comfortline  2008      157.0         blue
# 4  Volkswagen  Jetta     1.2 TSI Trendline  2012      127.0  silver_gray
#
#   transmission      fuel      city    ad_date      price
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# unnamed                   int64
# customer_id              object
# advertisement_number      int64
# brand                    object
# model                    object
# variant                  object
# year                      int64
# kilometer               float64
# color                    object
# transmission             object
# fuel                     object
# city                     object
# ad_date                  object
# price                    object
# dtype: object

# %%
kat_df=df.select_dtypes(include= ["object"])

# %%
kat_df.head()
# Out:
#                 customer_id       brand  model               variant  \
# 0  5e179871bc3087fa6cb10a21  Volkswagen   Golf       1.6 FSi Midline
# 1  5e179871bc3087fa6cb10a22  Volkswagen   Golf  1.2 TSI Midline Plus
# 2  5e179871bc3087fa6cb10a23  Volkswagen  Jetta     1.2 TSI Trendline
# 3  5e179871bc3087fa6cb10a24  Volkswagen  Jetta   1.4 TSI Comfortline
# 4  5e179871bc3087fa6cb10a25  Volkswagen  Jetta     1.2 TSI Trendline
#
#          color transmission      fuel      city    ad_date      price
# 0     dark_red       manual  gasoline  Istanbul  2/28/2023  308.75 TL
# 1          red       manual  gasoline     Izmir  2/12/2023  705.25 TL
# 2        white       manual  gasoline   Erzurum  2/23/2023   468.0 TL
# 3         blue       manual  gasoline   Kutahya  2/14/2023   422.5 TL
# 4  silver_gray       manual  gasoline   Kutahya   2/1/2023   507.0 TL

# %%
kat_df.tail(100)
# Out:
#                    customer_id       brand   model  \
# 7500  5e179871bc3087fa6cb12773         NaN  Passat
# 7501  5e179871bc3087fa6cb12774         NaN  Passat
# 7502  5e179871bc3087fa6cb12775         NaN    Golf
# 7503  5e179871bc3087fa6cb12776         NaN  Passat
# 7504  5e179871bc3087fa6cb12777         NaN  Passat
# ...                        ...         ...     ...
# 7595  5e179871bc3087fa6cb1264e  Volkswagen    Golf
# 7596  5e179871bc3087fa6cb1264f  Volkswagen  Passat
# 7597  5e179871bc3087fa6cb12650  Volkswagen    Golf
# 7598  5e179871bc3087fa6cb12651  Volkswagen  Passat
# 7599  5e179871bc3087fa6cb12651  Volkswagen  Passat
#
#                             variant        color transmission    fuel  \
# 7500            1.9 TDi Comfortline    dark_blue    automatic  diesel
# 7501              1.9 TDi Trendline  silver_gray    automatic  diesel
# 7502            1.9 TDi Comfortline         blue    automatic  diesel
# ...

# %%
kat_df["city"].value_counts()
# Out:
# city
# Istanbul    1451
# Ankara       798
# Izmir        367
# Antalya      351
# Konya        278
#             ...
# Ardahan        6
# Hakkari        5
# Artvin         5
# Diger          2
# Bayburt        1
# Name: count, Length: 82, dtype: int64

# %%
import matplotlib as plt
import seaborn as sns

# %%
kat_df["model"].value_counts()
# Out:
# model
# Passat            2327
# Polo              1627
# Golf              1447
# Jetta             1106
# Bora               390
# VW CC              376
# Scirocco           123
# Beetle              69
# Passat Variant      54
# Touran              28
# Arteon              24
# Phaeton             13
# Vento                6
# Lupo                 4
# EOS                  3
# Sharan               3
# Name: count, dtype: int64

# %%
kat_df["model"].value_counts().plot.barh()
# Out:
# <Axes: ylabel='model'>

# %%
kat_df["fuel"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='fuel'>

# %%
kat_df["fuel"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
int_df=df.select_dtypes(include= ["int64"])

# %%
int_df.head(20)
# Out:
#     Unnamed: 0  unnamed  advertisement_number  year
# 0            0    89732             777375802  2005
# 1            1    89733             777255310  2016
# 2            2    89734             776963108  2012
# 3            3    89735             776938945  2008
# 4            4    89736             776932300  2012
# 5            5    89737             753629836  2007
# 6            6    89738             765599247  2007
# 7            7    89739             776193128  2015
# 8            8    89740             776112847  2014
# 9            9    89741             776094322  2013
# 10          10    89742             775113711  2013
# 11          11    89743             775077140  2005
# 12          12    89744             777679752  2010
# 13          13    89745             777790331  2016
# 14          14    89746             777802832  2004
# 15          15    89747             777822013  2015
# 16          16    89748             777820536  2015
# ...

# %%
int_df["year"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='year'>

# %%
int_df["year"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>
